# %% [markdown]
# <h1 align="center">Name: Asad Haroon </h1>

# %% [markdown]
# <h1 align="center">Reg#: SP17-BCS-012</h1>

# %% [markdown]
# <h1 align="center">Section C</h1>

# %% [markdown]
# Note: I am Using Scipy v1.1.0. In case of any errors you can install scipy 1.1.0 by the following command:
# pip install scipy==1.1.0

# %%
import scipy
scipy.__version__
# Out:
# '1.1.0'

# %% [markdown]
# To download images Click on this url: https://drive.google.com/drive/folders/1pcaTwofZGfoCxZ3Hv2X6vW6xf_1i88eb?usp=sharing

# %% [markdown]
# # Import Libraries

# %%
from skimage import data
from scipy.misc import imread, imresize
import numpy as np
from scipy import ndimage
import matplotlib.pyplot as plt

# %% [markdown]
# # Original Image

# %%
original_image =imread('camera.png',True, 'L')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
processed_image=original_image.copy()
processed_image=processed_image.astype(np.int32)

# %% [markdown]
# # Helper Function

# %%
def returnNumber(x,b,m):
    a=(bin(x).replace("0b",''))
    a=[int(i) for i in a]
    count=8-len(a)
    for i in range(0,count):
        a.insert(i,0)
    a=m*a[b]
    return a

# %% [markdown]
# # Eight Bit Plane Slicing

# %%
#At 7bit plane
eight_bit_slice=processed_image.copy()
f=np.vectorize(returnNumber)
eight_bit_slice=f(eight_bit_slice,0,128)

# %%
plt.imshow(eight_bit_slice,plt.cm.gray)

# %% [markdown]
# # Seven Bit Plane Slicing

# %%
#At 6bit plane
seven_bit_slice=processed_image.copy()
f=np.vectorize(returnNumber)
seven_bit_slice=f(seven_bit_slice,1,64)

# %%
plt.imshow(seven_bit_slice,plt.cm.gray)

# %% [markdown]
# # Six Bit Plane Slicing

# %%
#At 5bit plane
six_bit_slice=processed_image.copy()
f=np.vectorize(returnNumber)
six_bit_slice=f(six_bit_slice,2,32)
print("Min intensity level is {} and Max intensity level is {}".format(np.amin(six_bit_slice),np.amax(six_bit_slice)))
# Out:
# Min intensity level is 0 and Max intensity level is 32

# %%
plt.imshow(six_bit_slice,plt.cm.gray)

# %% [markdown]
# # Five Bit Plane Slicing

# %%
#At 4bit plane
five_bit_slice=processed_image.copy()
f=np.vectorize(returnNumber)
five_bit_slice=f(five_bit_slice,3,16)
print("Min intensity level is {} and Max intensity level is {}".format(np.amin(five_bit_slice),np.amax(five_bit_slice)))
# Out:
# Min intensity level is 0 and Max intensity level is 16

# %%
plt.imshow(five_bit_slice,plt.cm.gray)

# %% [markdown]
# # Four Bit Plane Slicing

# %%
#At 3bit plane
four_bit_slice=processed_image.copy()
f=np.vectorize(returnNumber)
four_bit_slice=f(four_bit_slice,4,8)
print("Min intensity level is {} and Max intensity level is {}".format(np.amin(four_bit_slice),np.amax(four_bit_slice)))
# Out:
# Min intensity level is 0 and Max intensity level is 8

# %%
plt.imshow(five_bit_slice,plt.cm.gray)

# %% [markdown]
# # Three Bit Plane Slicing

# %%
#At 2 bit plane
three_bit_slice=processed_image.copy()
f=np.vectorize(returnNumber)
three_bit_slice=f(three_bit_slice,5,4)
print("Min intensity level is {} and Max intensity level is {}".format(np.amin(three_bit_slice),np.amax(three_bit_slice)))
# Out:
# Min intensity level is 0 and Max intensity level is 4

# %%
plt.imshow(three_bit_slice,plt.cm.gray)

# %% [markdown]
# # Two Bit Plane Slicing

# %%
# At 1th bit plane
two_bit_slice=processed_image.copy()
f=np.vectorize(returnNumber)
two_bit_slice=f(two_bit_slice,6,2)
print("Min intensity level is {} and Max intensity level is {}".format(np.amin(two_bit_slice),np.amax(two_bit_slice)))
# Out:
# Min intensity level is 0 and Max intensity level is 2

# %%
plt.imshow(two_bit_slice,plt.cm.gray)

# %% [markdown]
# # One Bit (i.e, at 0 bit) Plane Slicing

# %%
one_bit_slice=processed_image.copy()
f=np.vectorize(returnNumber)
one_bit_slice=f(one_bit_slice,7,0)
print("Min intensity level is {} and Max intensity level is {}".format(np.amin(one_bit_slice),np.amax(one_bit_slice)))
# Out:
# Min intensity level is 0 and Max intensity level is 0

# %%
plt.imshow(one_bit_slice,plt.cm.gray)

# %% [markdown]
# <h1 align="center">Concat of Bit planes</h1>

# %%
#8+7 bit 
eight_seven_bit=eight_bit_slice+seven_bit_slice
plt.imshow(eight_seven_bit,plt.cm.gray)

# %%
#8+7+6 bit 
eight_seven_six_bit=eight_bit_slice+seven_bit_slice+six_bit_slice
plt.imshow(eight_seven_six_bit,plt.cm.gray)

# %%
#8+7+6+5 bit 
eight_seven_six_5_bit=eight_bit_slice+seven_bit_slice+six_bit_slice+five_bit_slice
plt.imshow(eight_seven_six_5_bit,plt.cm.gray)

# %%
#8+7+6+5+4 bit 
eight_seven_six_5_4_bit=eight_bit_slice+seven_bit_slice+six_bit_slice+five_bit_slice+four_bit_slice
plt.imshow(eight_seven_six_5_4_bit,plt.cm.gray)

# %%
#8+7+6+5+4+3 bit 
eight_seven_six_5_4_3_bit=eight_bit_slice+seven_bit_slice+six_bit_slice+five_bit_slice+four_bit_slice+three_bit_slice
plt.imshow(eight_seven_six_5_4_3_bit,plt.cm.gray)

# %%
#8+7+6+5+4+3+2 bit 
eight_seven_six_5_4_3_2_bit=eight_bit_slice+seven_bit_slice+six_bit_slice+five_bit_slice+four_bit_slice+three_bit_slice+two_bit_slice
plt.imshow(eight_seven_six_5_4_3_2_bit,plt.cm.gray)

# %%
#8+7+6+5+4+3+2+1 bit 
all_bits=eight_bit_slice+seven_bit_slice+six_bit_slice+five_bit_slice+four_bit_slice+three_bit_slice+two_bit_slice+one_bit_slice
plt.imshow(all_bits,plt.cm.gray)

# %%
# As you can see original image and image made by bit plane slicing is not equal because in bit plane slicing, it discards few bit planes for compression
np.equal(processed_image,all_bits)
# Out:
# array([[ True, False,  True, ...,  True,  True,  True],
#        [ True, False, False, ...,  True,  True,  True],
#        [ True, False,  True, ...,  True,  True,  True],
#        ...,
#        [False, False,  True, ..., False, False, False],
#        [False, False,  True, ..., False, False, False],
#        [False, False,  True, ..., False, False, False]])
